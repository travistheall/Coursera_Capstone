# %%
import numpy as np
import pandas as pd
from pandas import json_normalize

import requests
import json

from geopy.geocoders import Nominatim
from IPython.display import Image 
from IPython.core.display import HTML     
import folium
from sklearn.cluster import KMeans
from sklearn import metrics 
from scipy.spatial.distance import cdist 


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
neighCenterData = pd.read_excel('../data/Geolocation/NeighborhoodMaxMinCenter.xlsx')

# %%
neighCenterData = pd.read_excel('../data/Geolocation/NeighborhoodMaxMinCenter.xlsx')
indexs = neighCenterData.where(neighCenterData['Zillow Home Value Index']=='Null').dropna()['Zillow Home Value Index'].index
for i in indexs:
    neighCenterData.at[i, 'Zillow Home Value Index']=np.NaN

# %%
neighCenterData.iloc[5]['Zillow Home Value Index']
# Out:
# nan

# %%
brMaxLatX = neighCenterData["Max Latitude"].max()
brMinLatX = neighCenterData["Min Latitude"].min()
brMaxLongY = neighCenterData["Max Longitude"].max()
brMinLongY = neighCenterData["Min Longitude"].min()

brCenterLat = np.add(brMinLatX, np.divide(np.subtract(brMaxLatX, brMinLatX), 2))
brCenterLong = np.add(brMinLongY, np.divide(np.subtract(brMaxLongY, brMinLongY), 2))

# %%
geojson = requests.get('https://opendata.arcgis.com/datasets/7c5e82ef83834de2ad2478efc86744ae_0.geojson').json()

# %%
CLIENT_ID='XLQ4AOQ1EPWQSLRZTS2J253I2KIEUF5QOIC3TEQ2T2HKCQIW'
CLIENT_SECRET = 'CZ2KUW1Z2FQ2VI3B5AOUTXNKL3BWPBODJ2XVEYCBPUZQZ3AR'

def getNearbyVenues(names, radius, latitudes, longitudes):
    section = 'food'
    sortByPopularity = 1
    VERSION = '20200805'
    LIMIT = 5
    venues_list = []
    for name, radius, lat, lng in zip(names, radius, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&section={}&limit={}&sortByPopularity={}'.format(
            CLIENT_ID,
            CLIENT_SECRET,
            VERSION,
            lat,
            lng,
            radius,
            section,
            LIMIT,
            sortByPopularity)

        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']

        # return only relevant information for each nearby venue
        venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood',
                             'Neighborhood Latitude',
                             'Neighborhood Longitude',
                             'Venue',
                             'Venue Latitude',
                             'Venue Longitude',
                             'Venue Category']

    return (nearby_venues)

# %%
"""br_venues = getNearbyVenues(names=neighCenterData['Neighborhood'],
                            radius=neighCenterData['Radius'],
                            latitudes=neighCenterData['Center Latitude'],
                            longitudes=neighCenterData['Center Longitude'])
br_venues.to_excel('../data/FoursquareAPI/br_food_w_Coord.xlsx')"""
br_venues = pd.read_excel('../data/FoursquareAPI/br_food_w_Coord.xlsx')
br_venues.head(10)
# Out:
#    Unnamed: 0                          Neighborhood  Neighborhood Latitude  \
# 0           0                                 BAKER              30.580547
# 1           1                                 BAKER              30.580547
# 2           2                                 BAKER              30.580547
# 3           3                                 BAKER              30.580547
# 4           4                                 BAKER              30.580547
# 5           5  BOCAGE / CITIPLACE / CONCORD ESTATES              30.418137
# 6           6  BOCAGE / CITIPLACE / CONCORD ESTATES              30.418137
# 7           7  BOCAGE / CITIPLACE / CONCORD ESTATES              30.418137
# 8           8  BOCAGE / CITIPLACE / CONCORD ESTATES              30.418137
# 9           9  BOCAGE / CITIPLACE / CONCORD ESTATES              30.418137
#
#    Neighborhood Longitude                      Venue  Venue Latitude  \
# 0              -91.163706            Jack in the Box       30.551975
# 1              -91.163706                 McDonald's       30.576206
# 2              -91.163706                Burger King       30.559097
# 3              -91.163706                 McDonald's       30.558392
# 4              -91.163706      Lagniappe (Plank Rd.)       30.575238
# 5              -91.119681                Chick-fil-A       30.419951
# 6              -91.119681                       IHOP       30.420917
# 7              -91.119681               Jimmy John's       30.406114
# 8              -91.119681               Waffle House       30.426663
# 9              -91.119681  Drago's Seafood Resturant       30.422191
#
#    Venue Longitude        Venue Category
# 0       -91.134962  Fast Food Restaurant
# 1       -91.169984  Fast Food Restaurant
# 2       -91.132777  Fast Food Restaurant
# 3       -91.133873  Fast Food Restaurant
# 4       -91.127551    Seafood Restaurant
# 5       -91.140519  Fast Food Restaurant
# 6       -91.140840        Breakfast Spot
# 7       -91.102183        Sandwich Place
# 8       -91.136962        Breakfast Spot
# 9       -91.138566    Seafood Restaurant

# %%
br_data = br_venues[['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude']].reset_index(drop=True)

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# one hot encoding
br_onehot = pd.get_dummies(br_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
br_onehot['Neighborhood'] = br_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [br_onehot.columns[-1]] + list(br_onehot.columns[:-1])
br_onehot = br_onehot[fixed_columns]

print("BR ONE HOT SHAPE, ", br_onehot.shape)

br_grouped = br_onehot.groupby('Neighborhood').mean().reset_index()
print("BR GROUPED SHAPE, ", br_grouped.shape)
# Out:
# BR ONE HOT SHAPE,  (289, 32)
# BR GROUPED SHAPE,  (58, 32)

# %%
num_top_venues = 5

for hood in br_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = br_grouped[br_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----BAKER----
#                    venue  freq
# 0   Fast Food Restaurant   0.8
# 1     Seafood Restaurant   0.2
# 2    American Restaurant   0.0
# 3       Greek Restaurant   0.0
# 4  Vietnamese Restaurant   0.0
#
#
# ----BOCAGE / CITIPLACE / CONCORD ESTATES----
#                   venue  freq
# 0        Breakfast Spot   0.4
# 1    Seafood Restaurant   0.2
# 2        Sandwich Place   0.2
# 3  Fast Food Restaurant   0.2
# 4   American Restaurant   0.0
#
#
# ----BROADMOOR----
#                   venue  freq
# 0   American Restaurant   0.2
# 1          Burger Joint   0.2
# 2   Fried Chicken Joint   0.2
# 3  Fast Food Restaurant   0.2
# 4    Chinese Restaurant   0.2
#
#
# ----BROOKSTOWN----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1        Breakfast Spot   0.2
# 2    Seafood Restaurant   0.2
# 3            Donut Shop   0.2
# 4   American Restaurant   0.0
#
#
# ----BROWNSFIELD----
#                    venue  freq
# 0   Fast Food Restaurant   0.8
# 1     Seafood Restaurant   0.2
# 2    American Restaurant   0.0
# 3       Greek Restaurant   0.0
# 4  Vietnamese Restaurant   0.0
#
#
# ----CENTRAL----
#                   venue  freq
# 0  Fast Food Restaurant   0.6
# 1           Pizza Place   0.2
# 2    Mexican Restaurant   0.2
# 3   American Restaurant   0.0
# 4      Greek Restaurant   0.0
#
#
# ----CITY PARK----
#                 venue  freq
# 0           Gastropub   0.2
# 1                Café   0.2
# 2      Sandwich Place   0.2
# 3         Pizza Place   0.2
# 4  Italian Restaurant   0.2
#
#
# ----COLLEGE TOWN----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1                Bakery   0.2
# 2            Restaurant   0.2
# 3    Mexican Restaurant   0.2
# 4   American Restaurant   0.0
#
#
# ----CORTANA / VILLA DEL REY----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1        Sandwich Place   0.2
# 2        Breakfast Spot   0.2
# 3   Fried Chicken Joint   0.2
# 4            Restaurant   0.0
#
#
# ----DELMONT PLACE----
#                   venue  freq
# 0   American Restaurant   0.2
# 1   Fried Chicken Joint   0.2
# 2  Fast Food Restaurant   0.2
# 3    Seafood Restaurant   0.2
# 4            Donut Shop   0.2
#
#
# ----DOWNTOWN----
#                        venue  freq
# 0        American Restaurant   0.2
# 1                       Café   0.2
# 2  Cajun / Creole Restaurant   0.2
# 3                Pizza Place   0.2
# 4         Italian Restaurant   0.2
#
#
# ----DOWNTOWN EAST----
#                      venue  freq
# 0      American Restaurant   0.4
# 1     Fast Food Restaurant   0.4
# 2  New American Restaurant   0.2
# 3         Greek Restaurant   0.0
# 4    Vietnamese Restaurant   0.0
#
#
# ----EAST FAIRFIELDS / MELROSE PLACE----
#                    venue  freq
# 0   Fast Food Restaurant   0.4
# 1                   Food   0.4
# 2    American Restaurant   0.2
# 3          Hot Dog Joint   0.0
# 4  Vietnamese Restaurant   0.0
#
#
# ----EDEN PARK----
#                    venue  freq
# 0                   Food  0.75
# 1                 Bakery  0.25
# 2    American Restaurant  0.00
# 3          Hot Dog Joint  0.00
# 4  Vietnamese Restaurant  0.00
#
#
# ----FAIRFIELDS----
#                  venue  freq
# 0                 Food   0.4
# 1  American Restaurant   0.2
# 2               Bakery   0.2
# 3          Snack Place   0.2
# 4        Hot Dog Joint   0.0
#
#
# ----FAIRWOOD----
#                   venue  freq
# 0         Deli / Bodega   0.2
# 1   Fried Chicken Joint   0.2
# 2                  Food   0.2
# 3  Fast Food Restaurant   0.2
# 4          Noodle House   0.2
#
#
# ----FOREST HEIGHTS / SUNNYBROOK----
#                        venue  freq
# 0       Fast Food Restaurant   0.4
# 1             Breakfast Spot   0.2
# 2  Cajun / Creole Restaurant   0.2
# 3             Sandwich Place   0.2
# 4        American Restaurant   0.0
#
#
# ----GLEN OAKS / ZION CITY----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1        Sandwich Place   0.2
# 2        Breakfast Spot   0.2
# 3   Fried Chicken Joint   0.2
# 4            Restaurant   0.0
#
#
# ----GOODWOOD----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1    Mexican Restaurant   0.2
# 2   Fried Chicken Joint   0.2
# 3             Cafeteria   0.2
# 4   American Restaurant   0.0
#
#
# ----GOODWOOD HOMESITES----
#                    venue  freq
# 0   Fast Food Restaurant   0.8
# 1         Breakfast Spot   0.2
# 2    American Restaurant   0.0
# 3          Hot Dog Joint   0.0
# 4  Vietnamese Restaurant   0.0
#
#
# ----ISTROUMA / DIXIE----
#                        venue  freq
# 0                Pizza Place   0.4
# 1        Fried Chicken Joint   0.2
# 2       Fast Food Restaurant   0.2
# 3  Cajun / Creole Restaurant   0.2
# 4        American Restaurant   0.0
#
#
# ----JEFFERSON / DRUSILLA----
#                        venue  freq
# 0        American Restaurant   0.2
# 1  Cajun / Creole Restaurant   0.2
# 2             Sandwich Place   0.2
# 3                Pizza Place   0.2
# 4                  BBQ Joint   0.2
#
#
# ----JEFFERSON / TIGER BEND----
#                    venue  freq
# 0   Fast Food Restaurant   0.6
# 1    American Restaurant   0.2
# 2     Seafood Restaurant   0.2
# 3       Greek Restaurant   0.0
# 4  Vietnamese Restaurant   0.0
#
#
# ----JEFFERSON TERRACE / INNISWOLD----
#                   venue  freq
# 0  Fast Food Restaurant   0.6
# 1          Burger Joint   0.2
# 2            Steakhouse   0.2
# 3   American Restaurant   0.0
# 4         Hot Dog Joint   0.0
#
#
# ----JONES CREEK----
#                        venue  freq
# 0       Fast Food Restaurant   0.4
# 1        Fried Chicken Joint   0.2
# 2                       Food   0.2
# 3  Cajun / Creole Restaurant   0.2
# 4        American Restaurant   0.0
#
#
# ----KENILWORTH----
#                  venue  freq
# 0          Pizza Place   0.4
# 1               Bakery   0.2
# 2           Restaurant   0.2
# 3   Italian Restaurant   0.2
# 4  American Restaurant   0.0
#
#
# ----KLEINPETER----
#                   venue  freq
# 0  Fast Food Restaurant   0.6
# 1          Burger Joint   0.2
# 2    Mexican Restaurant   0.2
# 3   American Restaurant   0.0
# 4         Hot Dog Joint   0.0
#
#
# ----L S U----
#                        venue  freq
# 0       Fast Food Restaurant   0.4
# 1        Fried Chicken Joint   0.2
# 2  Cajun / Creole Restaurant   0.2
# 3              Hot Dog Joint   0.2
# 4        American Restaurant   0.0
#
#
# ----LEGION VILLAGE----
#                   venue  freq
# 0   American Restaurant   0.2
# 1   Fried Chicken Joint   0.2
# 2  Fast Food Restaurant   0.2
# 3    Seafood Restaurant   0.2
# 4            Donut Shop   0.2
#
#
# ----MAYFAIR----
#                    venue  freq
# 0   Fast Food Restaurant   0.6
# 1  Vietnamese Restaurant   0.2
# 2    Fried Chicken Joint   0.2
# 3    American Restaurant   0.0
# 4          Hot Dog Joint   0.0
#
#
# ----MID CITY----
#                   venue  freq
# 0   Fried Chicken Joint   0.4
# 1    Mexican Restaurant   0.2
# 2                  Food   0.2
# 3  Fast Food Restaurant   0.2
# 4   American Restaurant   0.0
#
#
# ----MILLERVILLE----
#                        venue  freq
# 0                 Donut Shop   0.2
# 1                     Bakery   0.2
# 2             Breakfast Spot   0.2
# 3  Cajun / Creole Restaurant   0.2
# 4       Fast Food Restaurant   0.2
#
#
# ----MONTICELLO----
#                        venue  freq
# 0        American Restaurant   0.2
# 1         Seafood Restaurant   0.2
# 2                 Donut Shop   0.2
# 3  Cajun / Creole Restaurant   0.2
# 4         Chinese Restaurant   0.2
#
#
# ----NORTH BATON ROUGE----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1          Burger Joint   0.2
# 2    Seafood Restaurant   0.2
# 3        Sandwich Place   0.2
# 4   American Restaurant   0.0
#
#
# ----NORTH SHERWOOD FOREST----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1             BBQ Joint   0.2
# 2   Fried Chicken Joint   0.2
# 3                  Food   0.2
# 4   American Restaurant   0.0
#
#
# ----O'NEAL----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1    Seafood Restaurant   0.2
# 2   Fried Chicken Joint   0.2
# 3    Italian Restaurant   0.2
# 4   American Restaurant   0.0
#
#
# ----OLD SOUTH BATON ROUGE----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1    Chinese Restaurant   0.2
# 2                 Diner   0.2
# 3         Hot Dog Joint   0.2
# 4            Restaurant   0.0
#
#
# ----PARK FOREST / OAKCREST----
#                   venue  freq
# 0  Fast Food Restaurant   0.6
# 1           Pizza Place   0.2
# 2                  Food   0.2
# 3   American Restaurant   0.0
# 4         Hot Dog Joint   0.0
#
#
# ----PERKINS / HIGHLAND----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1   American Restaurant   0.2
# 2            Steakhouse   0.2
# 3            Restaurant   0.2
# 4      Greek Restaurant   0.0
#
#
# ----POLLARD / WOODCHASE----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1    Chinese Restaurant   0.2
# 2            Restaurant   0.2
# 3   Fried Chicken Joint   0.2
# 4    Mexican Restaurant   0.0
#
#
# ----PORT HUDSON----
#                        venue  freq
# 0         Seafood Restaurant   0.2
# 1  Cajun / Creole Restaurant   0.2
# 2                Pizza Place   0.2
# 3         Mexican Restaurant   0.2
# 4        Fried Chicken Joint   0.2
#
#
# ----PRIDE / CHANEYVILLE----
#                  venue  freq
# 0  Fried Chicken Joint   0.4
# 1  American Restaurant   0.2
# 2   Seafood Restaurant   0.2
# 3   Mexican Restaurant   0.2
# 4     Greek Restaurant   0.0
#
#
# ----SCOTLANDVILLE----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1   American Restaurant   0.2
# 2   Fried Chicken Joint   0.2
# 3           Wings Joint   0.2
# 4          Burger Joint   0.0
#
#
# ----SHENANDOAH----
#                  venue  freq
# 0  Fried Chicken Joint   0.4
# 1           Steakhouse   0.2
# 2   Seafood Restaurant   0.2
# 3   Italian Restaurant   0.2
# 4  American Restaurant   0.0
#
#
# ----SHERWOOD FOREST----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1         Deli / Bodega   0.2
# 2             BBQ Joint   0.2
# 3                  Food   0.2
# 4   American Restaurant   0.0
#
#
# ----SMILEY HEIGHTS / MELROSE EAST----
#                   venue  freq
# 0        Sandwich Place   0.4
# 1    Chinese Restaurant   0.2
# 2         Deli / Bodega   0.2
# 3  Fast Food Restaurant   0.2
# 4    Mexican Restaurant   0.0
#
#
# ----SOUTH BLUEBONNET / NICHOLSON----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1          Burger Joint   0.2
# 2            Restaurant   0.2
# 3    Mexican Restaurant   0.2
# 4   American Restaurant   0.0
#
#
# ----SOUTH BURBANK----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1    Tex-Mex Restaurant   0.2
# 2           Pizza Place   0.2
# 3   Fried Chicken Joint   0.2
# 4   American Restaurant   0.0
#
#
# ----SOUTH CAMPUS----
#                        venue  freq
# 0       Fast Food Restaurant   0.4
# 1           Greek Restaurant   0.2
# 2         Seafood Restaurant   0.2
# 3  Cajun / Creole Restaurant   0.2
# 4                Pizza Place   0.0
#
#
# ----SOUTHSIDE----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1             BBQ Joint   0.2
# 2        Breakfast Spot   0.2
# 3    Seafood Restaurant   0.2
# 4   American Restaurant   0.0
#
#
# ----STEVENDALE----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1        Breakfast Spot   0.2
# 2    Tex-Mex Restaurant   0.2
# 3            Donut Shop   0.2
# 4   American Restaurant   0.0
#
#
# ----TARA----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1   American Restaurant   0.2
# 2                Bakery   0.2
# 3   Fried Chicken Joint   0.2
# 4            Restaurant   0.0
#
#
# ----THE AVENUES / SOUTHERN UNIV----
#                   venue  freq
# 0   Fried Chicken Joint   0.4
# 1   American Restaurant   0.2
# 2  Fast Food Restaurant   0.2
# 3           Wings Joint   0.2
# 4          Burger Joint   0.0
#
#
# ----UNIVERSITY ACRES / WOODSTONE----
#                 venue  freq
# 0              Bakery   0.2
# 1        Burger Joint   0.2
# 2  Tex-Mex Restaurant   0.2
# 3          Restaurant   0.2
# 4         Pizza Place   0.2
#
#
# ----VALLEY PARK----
#                   venue  freq
# 0        Breakfast Spot   0.4
# 1  Fast Food Restaurant   0.4
# 2    Seafood Restaurant   0.2
# 3   American Restaurant   0.0
# 4         Hot Dog Joint   0.0
#
#
# ----VICTORIA FARMS----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1        Sandwich Place   0.2
# 2           Pizza Place   0.2
# 3   Fried Chicken Joint   0.2
# 4   American Restaurant   0.0
#
#
# ----WESTMINSTER / PINE PARK----
#                        venue  freq
# 0       Fast Food Restaurant   0.4
# 1        American Restaurant   0.2
# 2  Cajun / Creole Restaurant   0.2
# 3             Sandwich Place   0.2
# 4              Hot Dog Joint   0.0
#
#
# ----ZACHARY----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1   American Restaurant   0.2
# 2            Restaurant   0.2
# 3   Fried Chicken Joint   0.2
# 4         Hot Dog Joint   0.0

# %%
def return_most_popular_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Popular Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Popular Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = br_grouped['Neighborhood']

for ind in np.arange(br_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_popular_venues(br_grouped.iloc[ind, :], num_top_venues)

# %%
neighborhoods_venues_sorted.head()
# Out:
#                            Neighborhood 1st Most Popular Venue  \
# 0                                 BAKER   Fast Food Restaurant
# 1  BOCAGE / CITIPLACE / CONCORD ESTATES         Breakfast Spot
# 2                             BROADMOOR    American Restaurant
# 3                            BROOKSTOWN   Fast Food Restaurant
# 4                           BROWNSFIELD   Fast Food Restaurant
#
#   2nd Most Popular Venue 3rd Most Popular Venue 4th Most Popular Venue  \
# 0     Seafood Restaurant            Wings Joint    Fried Chicken Joint
# 1     Seafood Restaurant         Sandwich Place   Fast Food Restaurant
# 2    Fried Chicken Joint           Burger Joint     Chinese Restaurant
# 3         Breakfast Spot     Seafood Restaurant             Donut Shop
# 4     Seafood Restaurant            Wings Joint    Fried Chicken Joint
#
#   5th Most Popular Venue
# 0              BBQ Joint
# 1            Wings Joint
# 2   Fast Food Restaurant
# 3            Wings Joint
# 4              BBQ Joint

# %%
br_grouped_clustering = br_grouped.drop('Neighborhood', 1)
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,10)
X = br_grouped_clustering

for k in K: 
    kmeanModel = KMeans(n_clusters=k).fit(X) 
    kmeanModel.fit(X)     
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'),axis=1)) / X.shape[0])   
    inertias.append(kmeanModel.inertia_) 
    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'),axis=1)) / X.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
plt.plot(K, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()

# %%
plt.plot(K, inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %%
kclusters = 2
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(br_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 1, 0, 0, 0, 1, 0, 0, 1], dtype=int32)

# %%
#neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
neighborhoods_venues_sorted['Cluster Labels']=kmeans.labels_

# %%
br_merged = br_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
br_merged = br_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood').drop_duplicates()
br_merged = pd.merge(br_merged, neighCenterData[['Neighborhood', "Zillow Home Value Index"]], on='Neighborhood')
br_merged.head() # check the last columns!
# Out:
#                            Neighborhood  Neighborhood Latitude  \
# 0                                 BAKER              30.580547
# 1  BOCAGE / CITIPLACE / CONCORD ESTATES              30.418137
# 2                             BROADMOOR              30.444104
# 3                            BROOKSTOWN              30.498502
# 4                           BROWNSFIELD              30.570289
#
#    Neighborhood Longitude 1st Most Popular Venue 2nd Most Popular Venue  \
# 0              -91.163706   Fast Food Restaurant     Seafood Restaurant
# 1              -91.119681         Breakfast Spot     Seafood Restaurant
# 2              -91.080473    American Restaurant    Fried Chicken Joint
# 3              -91.137226   Fast Food Restaurant         Breakfast Spot
# 4              -91.118204   Fast Food Restaurant     Seafood Restaurant
#
#   3rd Most Popular Venue 4th Most Popular Venue 5th Most Popular Venue  \
# 0            Wings Joint    Fried Chicken Joint              BBQ Joint
# 1         Sandwich Place   Fast Food Restaurant            Wings Joint
# 2           Burger Joint     Chinese Restaurant   Fast Food Restaurant
# 3     Seafood Restaurant             Donut Shop            Wings Joint
# 4            Wings Joint    Fried Chicken Joint              BBQ Joint
#
#    Cluster Labels Zillow Home Value Index
# 0               0                   95800
# 1               0                  233900
# 2               1                  176200
# 3               0                   63600
# 4               0                  129900

# %%
geojsonNotNull = neighCenterData[['Neighborhood', 'Zillow Home Value Index']].dropna()

# %%
# create map
map_clusters = folium.Map(location=[brCenterLat, brCenterLong], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map

folium.Choropleth(
    geo_data=geojson,
    name='choropleth',
    data=geojsonNotNull,
    columns=['Neighborhood', 'Zillow Home Value Index'],
    key_on='feature.properties.NEIGHBORHOOD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Zillow Housing Index').add_to(map_clusters)

markers_colors = []
for lat, lon, poi, cluster, cost, fir, sec, thi in zip(br_merged['Neighborhood Latitude'],
                                                         br_merged['Neighborhood Longitude'],
                                                         br_merged['Neighborhood'],
                                                         br_merged['Cluster Labels'],
                                                         br_merged['Zillow Home Value Index'],
                                                         br_merged['1st Most Popular Venue'],
                                                         br_merged['2nd Most Popular Venue'],
                                                         br_merged['3rd Most Popular Venue'],):
    labels = [f'{poi}, Cluster {cluster}',
              f'Housing Index: ${cost}',
              'Most Popular Restaurants:',
              f'1) {fir}',
              f'2) {sec}',
              f'3) {thi}']
    nl = '\n'
    label = folium.Popup(f"{nl}{nl.join(labels)}", parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
noextra = br_merged[['Cluster Labels',"1st Most Popular Venue"]]
clust0 = noextra[noextra['Cluster Labels']==0].reset_index()
clust0MostPopList = list(clust0["1st Most Popular Venue"].unique())
y = [clust0.where(clust0["1st Most Popular Venue"]==mostPopular).dropna()["1st Most Popular Venue"].count() for mostPopular in clust0MostPopList]
counts0 = noextra.set_index('Cluster Labels').loc[0].groupby('1st Most Popular Venue').agg(len)
counts0['number']=y

# %%
height = counts0['number']
bars = counts0.index
y_pos = np.arange(len(bars))
plt.bar(y_pos, height)
plt.figsize=(50,50)
plt.xticks(y_pos, bars, rotation=90)
plt.xlabel('Cluster 0')
plt.yticks(color='red')
plt.show()

# %%
clust1 = noextra[noextra['Cluster Labels']==1].reset_index()
clust1MostPopList = list(clust1["1st Most Popular Venue"].unique())
y = [clust1.where(clust1["1st Most Popular Venue"]==mostPopular).dropna()["1st Most Popular Venue"].count() for mostPopular in clust1MostPopList]
counts1 = noextra.set_index('Cluster Labels').loc[1].groupby('1st Most Popular Venue').agg(len)
counts1['number']=y

# %%
height1 = counts1['number']
bars1 = counts1.index
y_pos1 = np.arange(len(bars1))
plt.bar(y_pos1, height1)
plt.figsize=(50,50)
plt.xticks(y_pos1, bars1, rotation=90)
plt.yticks(color='red')
plt.xlabel('Cluster 1')
plt.show()

# %%
clust0DF = br_merged.loc[br_merged['Cluster Labels'] == 0, br_merged.columns[[0] + list(range(3, br_merged.shape[1]))]].sort_values(by='Zillow Home Value Index',ascending=False)
print("Average Home Index: ", clust0DF['Zillow Home Value Index'].mean())
clust0DF
# Out:
# Average Home Index:  186993.24324324325
#                             Neighborhood 1st Most Popular Venue  \
# 46          SOUTH BLUEBONNET / NICHOLSON   Fast Food Restaurant
# 39                   POLLARD / WOODCHASE   Fast Food Restaurant
# 26                            KLEINPETER   Fast Food Restaurant
# 49                             SOUTHSIDE   Fast Food Restaurant
# 38                    PERKINS / HIGHLAND   Fast Food Restaurant
# 7                           COLLEGE TOWN   Fast Food Restaurant
# 51                                  TARA   Fast Food Restaurant
# 57                               ZACHARY   Fast Food Restaurant
# 18                              GOODWOOD   Fast Food Restaurant
# 23         JEFFERSON TERRACE / INNISWOLD   Fast Food Restaurant
# 1   BOCAGE / CITIPLACE / CONCORD ESTATES         Breakfast Spot
# 54                           VALLEY PARK         Breakfast Spot
# 22                JEFFERSON / TIGER BEND   Fast Food Restaurant
# 35                                O'NEAL   Fast Food Restaurant
# 24                           JONES CREEK   Fast Food Restaurant
# 56               WESTMINSTER / PINE PARK   Fast Food Restaurant
# 44                       SHERWOOD FOREST   Fast Food Restaurant
# 29                               MAYFAIR   Fast Food Restaurant
# 48                          SOUTH CAMPUS   Fast Food Restaurant
# 47                         SOUTH BURBANK   Fast Food Restaurant
# 11                         DOWNTOWN EAST    American Restaurant
# 8                CORTANA / VILLA DEL REY   Fast Food Restaurant
# 12       EAST FAIRFIELDS / MELROSE PLACE   Fast Food Restaurant
# 37                PARK FOREST / OAKCREST   Fast Food Restaurant
# 50                            STEVENDALE   Fast Food Restaurant
# 19                    GOODWOOD HOMESITES   Fast Food Restaurant
# 27                                 L S U   Fast Food Restaurant
# 4                            BROWNSFIELD   Fast Food Restaurant
# 16           FOREST HEIGHTS / SUNNYBROOK   Fast Food Restaurant
# 34                 NORTH SHERWOOD FOREST   Fast Food Restaurant
# 36                 OLD SOUTH BATON ROUGE   Fast Food Restaurant
# 0                                  BAKER   Fast Food Restaurant
# 55                        VICTORIA FARMS   Fast Food Restaurant
# 17                 GLEN OAKS / ZION CITY   Fast Food Restaurant
# 42                         SCOTLANDVILLE   Fast Food Restaurant
# 3                             BROOKSTOWN   Fast Food Restaurant
# 33                     NORTH BATON ROUGE   Fast Food Restaurant
# 5                                CENTRAL   Fast Food Restaurant
#
#    2nd Most Popular Venue     3rd Most Popular Venue  \
# 46           Burger Joint                 Restaurant
# 39    Fried Chicken Joint                 Restaurant
# 26           Burger Joint         Mexican Restaurant
# 49              BBQ Joint             Breakfast Spot
# 38    American Restaurant                 Steakhouse
# 7                  Bakery                 Restaurant
# 51    American Restaurant        Fried Chicken Joint
# 57    American Restaurant        Fried Chicken Joint
# 18    Fried Chicken Joint                  Cafeteria
# 23             Steakhouse               Burger Joint
# 1      Seafood Restaurant             Sandwich Place
# 54   Fast Food Restaurant         Seafood Restaurant
# 22    American Restaurant         Seafood Restaurant
# 35    Fried Chicken Joint         Seafood Restaurant
# 24    Fried Chicken Joint  Cajun / Creole Restaurant
# 56    American Restaurant             Sandwich Place
# 44              BBQ Joint              Deli / Bodega
# 29    Fried Chicken Joint      Vietnamese Restaurant
# 48     Seafood Restaurant  Cajun / Creole Restaurant
# 47            Pizza Place        Fried Chicken Joint
# 11   Fast Food Restaurant    New American Restaurant
# 8     Fried Chicken Joint             Breakfast Spot
# 12                   Food        American Restaurant
# 37            Pizza Place                       Food
# 50     Tex-Mex Restaurant             Breakfast Spot
# 19         Breakfast Spot                Wings Joint
# 27    Fried Chicken Joint  Cajun / Creole Restaurant
# 4      Seafood Restaurant                Wings Joint
# 16         Breakfast Spot             Sandwich Place
# 34    Fried Chicken Joint                  BBQ Joint
# 36     Chinese Restaurant                      Diner
# 0      Seafood Restaurant                Wings Joint
# 55            Pizza Place             Sandwich Place
# 17    Fried Chicken Joint             Breakfast Spot
# 42            Wings Joint        Fried Chicken Joint
# 3          Breakfast Spot         Seafood Restaurant
# 33     Seafood Restaurant             Sandwich Place
# 5             Pizza Place         Mexican Restaurant
#
#        4th Most Popular Venue     5th Most Popular Venue  Cluster Labels  \
# 46         Mexican Restaurant                Wings Joint               0
# 39         Chinese Restaurant                Wings Joint               0
# 26                Wings Joint        Fried Chicken Joint               0
# 49         Seafood Restaurant                Wings Joint               0
# 38                 Restaurant                       Food               0
# 7          Mexican Restaurant                Wings Joint               0
# 51                     Bakery                  BBQ Joint               0
# 57                 Restaurant                  BBQ Joint               0
# 18         Mexican Restaurant                Wings Joint               0
# 23                Wings Joint        Fried Chicken Joint               0
# 1        Fast Food Restaurant                Wings Joint               0
# 54                Wings Joint        Fried Chicken Joint               0
# 22        Fried Chicken Joint                  BBQ Joint               0
# 35         Italian Restaurant  Cajun / Creole Restaurant               0
# 24                       Food                Wings Joint               0
# 56  Cajun / Creole Restaurant        Fried Chicken Joint               0
# 44                       Food                Wings Joint               0
# 29                Wings Joint                  BBQ Joint               0
# 48           Greek Restaurant                Wings Joint               0
# 47         Tex-Mex Restaurant                  BBQ Joint               0
# 11        Fried Chicken Joint                  BBQ Joint               0
# 8              Sandwich Place                Wings Joint               0
# 12        Fried Chicken Joint                  BBQ Joint               0
# 37                Wings Joint        Fried Chicken Joint               0
# 50                 Donut Shop                Wings Joint               0
# 19        Fried Chicken Joint                  BBQ Joint               0
# 27              Hot Dog Joint                Wings Joint               0
# 4         Fried Chicken Joint                  BBQ Joint               0
# 16  Cajun / Creole Restaurant                Wings Joint               0
# 34                       Food                Wings Joint               0
# 36              Hot Dog Joint                Wings Joint               0
# 0         Fried Chicken Joint                  BBQ Joint               0
# 55        Fried Chicken Joint             Breakfast Spot               0
# 17             Sandwich Place                Wings Joint               0
# 42        American Restaurant                Snack Place               0
# 3                  Donut Shop                Wings Joint               0
# 33               Burger Joint                Wings Joint               0
# 5                 Wings Joint                       Food               0
#
#    Zillow Home Value Index
# 46                  443400
# 39                  364750
# 26                  358800
# 49                  339500
# 38                  285400
# 7                   276900
# 51                  271700
# 57                  250000
# 18                  240900
# 23                  240300
# 1                   233900
# 54                  211600
# 22                  207500
# 35                  205300
# 24                  204400
# 56                  183000
# 44                  182300
# 29                  165200
# 48                  156100
# 47                  153200
# 11                  151400
# 8                   145800
# 12                  144700
# 37                  144400
# 50                  140800
# 19                  140400
# 27                  138900
# 4                   129900
# 16                  124000
# 34                  106800
# 36                  100000
# 0                    95800
# 55                   93400
# 17                   84900
# 42                   81300
# 3                    63600
# 33                   58500
# 5                      NaN

# %%
clust1DF = br_merged.loc[br_merged['Cluster Labels'] == 1, br_merged.columns[[0] + list(range(3, br_merged.shape[1]))]].sort_values(by='Zillow Home Value Index',ascending=False)
print("Average Home Index: ", clust1DF['Zillow Home Value Index'].mean())
clust1DF
# Out:
# Average Home Index:  150594.11764705883
#                      Neighborhood 1st Most Popular Venue  \
# 53   UNIVERSITY ACRES / WOODSTONE            Pizza Place
# 6                       CITY PARK              Gastropub
# 25                     KENILWORTH            Pizza Place
# 43                     SHENANDOAH    Fried Chicken Joint
# 30                       MID CITY    Fried Chicken Joint
# 2                       BROADMOOR    American Restaurant
# 21           JEFFERSON / DRUSILLA    American Restaurant
# 31                    MILLERVILLE                 Bakery
# 15                       FAIRWOOD    Fried Chicken Joint
# 32                     MONTICELLO    American Restaurant
# 10                       DOWNTOWN    American Restaurant
# 52    THE AVENUES / SOUTHERN UNIV    Fried Chicken Joint
# 9                   DELMONT PLACE    American Restaurant
# 14                     FAIRFIELDS                   Food
# 20               ISTROUMA / DIXIE            Pizza Place
# 45  SMILEY HEIGHTS / MELROSE EAST         Sandwich Place
# 13                      EDEN PARK                   Food
# 28                 LEGION VILLAGE    American Restaurant
# 40                    PORT HUDSON            Pizza Place
# 41            PRIDE / CHANEYVILLE    Fried Chicken Joint
#
#    2nd Most Popular Venue     3rd Most Popular Venue  \
# 53     Tex-Mex Restaurant                     Bakery
# 6          Sandwich Place         Italian Restaurant
# 25                 Bakery         Italian Restaurant
# 43             Steakhouse         Seafood Restaurant
# 30     Mexican Restaurant       Fast Food Restaurant
# 2     Fried Chicken Joint               Burger Joint
# 21              BBQ Joint             Sandwich Place
# 31         Breakfast Spot  Cajun / Creole Restaurant
# 15           Noodle House              Deli / Bodega
# 32     Seafood Restaurant  Cajun / Creole Restaurant
# 10                   Café                Pizza Place
# 52            Wings Joint       Fast Food Restaurant
# 9     Fried Chicken Joint         Seafood Restaurant
# 14    American Restaurant                     Bakery
# 20    Fried Chicken Joint  Cajun / Creole Restaurant
# 45     Chinese Restaurant              Deli / Bodega
# 13                 Bakery                Wings Joint
# 28    Fried Chicken Joint         Seafood Restaurant
# 40     Seafood Restaurant         Mexican Restaurant
# 41     Seafood Restaurant         Mexican Restaurant
#
#        4th Most Popular Venue     5th Most Popular Venue  Cluster Labels  \
# 53               Burger Joint                 Restaurant               1
# 6                        Café                Pizza Place               1
# 25                 Restaurant  Cajun / Creole Restaurant               1
# 43         Italian Restaurant  Cajun / Creole Restaurant               1
# 30                       Food                Wings Joint               1
# 2          Chinese Restaurant       Fast Food Restaurant               1
# 21                Pizza Place  Cajun / Creole Restaurant               1
# 31                 Donut Shop       Fast Food Restaurant               1
# 15       Fast Food Restaurant                       Food               1
# 32         Chinese Restaurant                 Donut Shop               1
# 10  Cajun / Creole Restaurant         Italian Restaurant               1
# 52        American Restaurant                Snack Place               1
# 9                  Donut Shop       Fast Food Restaurant               1
# 14                Snack Place        Fried Chicken Joint               1
# 20       Fast Food Restaurant                Wings Joint               1
# 45       Fast Food Restaurant                Wings Joint               1
# 13        Fried Chicken Joint                  BBQ Joint               1
# 28                 Donut Shop       Fast Food Restaurant               1
# 40  Cajun / Creole Restaurant        Fried Chicken Joint               1
# 41        American Restaurant             Breakfast Spot               1
#
#    Zillow Home Value Index
# 53                  286500
# 6                   272000
# 25                  267200
# 43                  251600
# 30                  221400
# 2                   176200
# 21                  171600
# 31                  168800
# 15                  161100
# 32                  151900
# 10                  123200
# 52                   94800
# 9                    57000
# 14                   56800
# 20                   36800
# 45                   33100
# 13                   30100
# 28                     NaN
# 40                     NaN
# 41                     NaN
