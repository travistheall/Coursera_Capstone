# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('NAPSAC.xlsx')

# %%
df_oversample = df.where(df['IsOversample']==True)
x = df_oversample['TakenGrams'].where(df['UserName']=='Travis Theall').dropna()
y = df_oversample['TakenGrams'].where(df['UserName']=='Patrick Shamma').dropna()

# %%
plt.plot(x, y)
#plt.title('Taken Grams ICC')
#plt.xlabel('Travis Taken Grams')
#plt.ylabel('Patrick Taken Grams')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-1a903e020eb4> in <module>
# ----> 1 plt.plot(x, y)
#       2 #plt.title('Taken Grams ICC')
#       3 #plt.xlabel('Travis Taken Grams')
#       4 #plt.ylabel('Patrick Taken Grams')
#
# E:\Users\travi\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# E:\Users\travi\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# ...

# %%
df.describe()
# Out:
#             Folder      Subject       GramWt     TakenSrv  ReturnedSrv  \
# count  1992.000000  1992.000000  1992.000000  1992.000000  1992.000000
# mean   2622.410643     8.233936    45.400891     1.473062     0.283941
# std    1550.450786     6.258815    48.858605     1.389416     0.642397
# min    1021.000000     1.000000     0.800000     0.062500     0.000000
# 25%    1022.000000     3.000000    13.450000     1.000000     0.000000
# 50%    3001.000000     7.000000    28.000000     1.000000     0.000000
# 75%    3033.000000    11.000000    62.900000     1.500000     0.310000
# max    6003.000000    26.000000   500.000000    20.000000     8.000000
#
#        ConsumedSrv   TakenGrams  ReturnedGrams  ConsumedGrams  \
# count  1992.000000  1992.000000    1992.000000    1992.000000
# mean      1.189121    47.619166      10.083291      37.535875
# std       1.332412    44.998177      23.876338      40.006715
# min       0.000000     0.800000       0.000000       0.000000
# ...
